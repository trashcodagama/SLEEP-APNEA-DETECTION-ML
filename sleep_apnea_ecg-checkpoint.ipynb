# %%
import numpy as np
import pandas as pd
from mat4py import loadmat
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.utils import resample
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"  # or if you want more than 1 GPU set it as "0", "1"
import tensorflow
from tensorflow.keras.callbacks import ModelCheckpoint
import sklearn
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization,Concatenate,concatenate, Input
from tensorflow.keras.layers import Conv2D, Conv1D, MaxPooling1D
import matplotlib.pyplot as plt
import pickle

# %%
list_string=['ucddb002','ucddb003'\
             ]#'ucddb008','ucddb011','ucddb013','ucddb014','ucddb010','ucddb012','ucddb014','ucddb015','ucddb017',\'ucddb019','ucddb020','ucddb021','ucddb022','ucddb023','ucddb024',\'ucddb025','ucddb026','ucddb027','ucddb028','ucddb005','ucddb006','ucddb007','ucddb009'


valid_features=np.zeros((1,1408))
test_features=np.zeros((1,1408))
valid_labels=np.zeros((1,1))
test_labels=np.zeros((1,1))
for l in list_string:
        
        
        ecg_valid = loadmat('C:\\Users\\vedan\\Downloads\\SLEEP APNEA\\selected\\'+l+'_ecg_valid.mat') #displaying data in a good way
        ecg_valid = np.array(ecg_valid['ecg_valid'])
        ecg_valid_labels=loadmat('C:\\Users\\vedan\\Downloads\\SLEEP APNEA\\selected\\'+l+'_valid_labels.mat')
        ecg_valid_labels = np.array(ecg_valid_labels['class_valid'])
        valid_features=np.append(valid_features,ecg_valid,axis=0)
        valid_labels=np.append(valid_labels,ecg_valid_labels)
       
        
        ecg_test = loadmat('C:\\Users\\vedan\\Downloads\\SLEEP APNEA\\selected\\'+l+'_ecg_test.mat')
        ecg_test = np.array(ecg_test['ecg_test'])
        ecg_test_labels=loadmat('C:\\Users\\vedan\\Downloads\\SLEEP APNEA\\selected\\'+l+'_test_labels.mat')
        ecg_test_labels = np.array(ecg_test_labels['class_test'])
        test_features=np.append(test_features,ecg_test,axis=0)
        test_labels=np.append(test_labels,ecg_test_labels)
        
ecg_valid=valid_features[1:,:]
valid_labels=valid_labels[1:]
valid_labels = valid_labels.flatten()

ecg_test=test_features[1:,:]
test_labels=test_labels[1:]
test_labels = test_labels.flatten()

# %%
train_features=np.zeros((1,1408))

train_labels=np.zeros((1,1))

for l in list_string:
        ecg_train = loadmat('C:\\Users\\vedan\\Downloads\\SLEEP APNEA\\selected\\'+l+'_ecg_train.mat')
        ecg_train = np.array(ecg_train['ecg_train'])
        ecg_train_labels=loadmat('C:\\Users\\vedan\\Downloads\\SLEEP APNEA\\selected\\'+l+'_train_labels.mat')
        ecg_train_labels = np.array(ecg_train_labels['class_train'])
        train_features=np.append(train_features,ecg_train,axis=0)
        train_labels=np.append(train_labels,ecg_train_labels)
        
ecg_train=train_features[1:,:]
train_labels=train_labels[1:]
train_labels = train_labels.flatten()

# %%
ecg_train_mean=np.mean(ecg_train)
ecg_train_std=np.std(ecg_train)

# %%
for i in range(ecg_train.shape[0]):
    ecg_train[i,:]=(ecg_train[i,:]-ecg_train_mean)/ecg_train_std
    
for i in range(ecg_valid.shape[0]):
    ecg_valid[i,:]=(ecg_valid[i,:]-ecg_train_mean)/ecg_train_std
    
for i in range(ecg_test.shape[0]):
    ecg_test[i,:]=(ecg_test[i,:]-ecg_train_mean)/ecg_train_std
    
ecg_train=np.expand_dims(ecg_train, axis=2)
ecg_valid=np.expand_dims(ecg_valid, axis=2)
ecg_test=np.expand_dims(ecg_test, axis=2)

# %%
y_train=train_labels
y_valid=valid_labels
y_test=test_labels

# %%
tensorflow.keras.backend.clear_session()

# %%
num_classes=2

# %%
y_train_encoder = sklearn.preprocessing.LabelEncoder()
y_train_num = y_train_encoder.fit_transform(y_train)
y_train_wide = tensorflow.keras.utils.to_categorical(y_train_num, num_classes)

y_valid_num = y_train_encoder.fit_transform(y_valid)
y_valid_wide = tensorflow.keras.utils.to_categorical(y_valid_num, num_classes)

y_test_num = y_train_encoder.fit_transform(y_test)
y_test_wide = tensorflow.keras.utils.to_categorical(y_test_num, num_classes)

# %%
input_layer = Input(shape=(1408, 1))
x = BatchNormalization()(input_layer)
x = Conv1D(3, kernel_size=100, strides=2)(x)
x = Activation("relu")(x)
x = MaxPooling1D(pool_size=2, strides=2)(x)
x = Conv1D(50, 10)(x)
x = MaxPooling1D(pool_size=2, strides=2)(x)
x = Activation("relu")(x)
x = BatchNormalization()(x)
x = Flatten()(x)
x = Dropout(0.25)(x)
output_layer = Dense(2, activation='softmax', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01))(x)

model_ecg = Model(inputs=input_layer, outputs=output_layer)
model_ecg.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1408, 1)]         0
#
#  batch_normalization (BatchN  (None, 1408, 1)          4
#  ormalization)
#
#  conv1d (Conv1D)             (None, 655, 3)            303
#
#  activation (Activation)     (None, 655, 3)            0
#
#  max_pooling1d (MaxPooling1D  (None, 327, 3)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 318, 50)           1550
#
#  max_pooling1d_1 (MaxPooling  (None, 159, 50)          0
#  1D)
#
#  activation_1 (Activation)   (None, 159, 50)           0
#
#  batch_normalization_1 (Batc  (None, 159, 50)          200
#  hNormalization)
#
#  flatten (Flatten)           (None, 7950)              0
#
#  dropout (Dropout)           (None, 7950)              0
#
#  dense (Dense)               (None, 2)                 15902
#
# =================================================================
# Total params: 17,959
# Trainable params: 17,857
# Non-trainable params: 102
# _________________________________________________________________

# %%
batch_size = 32
epochs = 1

opt = tensorflow.keras.optimizers.Adam(lr=0.001)
model_ecg.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
print("Num GPUs Available: ", len(tensorflow.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
ecg_train.shape
# Out:
# (76698, 1408, 1)

# %%
best_weights_filepath_ecg = './best_weights_ecg_32layer.hdf5'

# %%
best_weights_filepath_ecg = './best_weights_ecg_32layer.hdf5'
mcp_ecg = ModelCheckpoint(best_weights_filepath_ecg, monitor="val_accuracy",
                      save_best_only=True, save_weights_only=False)
            
history = model_ecg.fit(ecg_train, y_train_wide,
         batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(ecg_valid, y_valid_wide),
          callbacks=[mcp_ecg])
# Out:
# Epoch 1/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.2414 - accuracy: 0.9323 - val_loss: 1.1260 - val_accuracy: 0.7274
# Epoch 2/100
# 2397/2397 [==============================] - 33s 14ms/step - loss: 0.1471 - accuracy: 0.9739 - val_loss: 0.8793 - val_accuracy: 0.8214
# Epoch 3/100
# 2397/2397 [==============================] - 36s 15ms/step - loss: 0.1275 - accuracy: 0.9801 - val_loss: 0.7627 - val_accuracy: 0.7743
# Epoch 4/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.1178 - accuracy: 0.9824 - val_loss: 0.6188 - val_accuracy: 0.8698
# Epoch 5/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.1136 - accuracy: 0.9832 - val_loss: 0.7023 - val_accuracy: 0.8468
# Epoch 6/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.1088 - accuracy: 0.9843 - val_loss: 0.5141 - val_accuracy: 0.8246
# Epoch 7/100
# 2397/2397 [==============================] - 36s 15ms/step - loss: 0.1036 - accuracy: 0.9862 - val_loss: 0.7065 - val_accuracy: 0.8356
# Epoch 8/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.1003 - accuracy: 0.9870 - val_loss: 0.5651 - val_accuracy: 0.8241
# Epoch 9/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0964 - accuracy: 0.9874 - val_loss: 0.7204 - val_accuracy: 0.7901
# Epoch 10/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0988 - accuracy: 0.9867 - val_loss: 0.4616 - val_accuracy: 0.9119
# Epoch 11/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0923 - accuracy: 0.9877 - val_loss: 0.6942 - val_accuracy: 0.8567
# Epoch 12/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0953 - accuracy: 0.9881 - val_loss: 0.2971 - val_accuracy: 0.9256
# Epoch 13/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0918 - accuracy: 0.9884 - val_loss: 0.3947 - val_accuracy: 0.8947
# Epoch 14/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0936 - accuracy: 0.9881 - val_loss: 0.2992 - val_accuracy: 0.9319
# Epoch 15/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0857 - accuracy: 0.9901 - val_loss: 0.4525 - val_accuracy: 0.8757
# Epoch 16/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0914 - accuracy: 0.9891 - val_loss: 0.4820 - val_accuracy: 0.9061
# Epoch 17/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0901 - accuracy: 0.9891 - val_loss: 0.7130 - val_accuracy: 0.8499
# Epoch 18/100
# 2397/2397 [==============================] - 36s 15ms/step - loss: 0.0741 - accuracy: 0.9943 - val_loss: 0.2547 - val_accuracy: 0.9397
# Epoch 56/100
# 2397/2397 [==============================] - 33s 14ms/step - loss: 0.0791 - accuracy: 0.9941 - val_loss: 0.3277 - val_accuracy: 0.9274
# Epoch 57/100
# 2397/2397 [==============================] - 32s 13ms/step - loss: 0.0772 - accuracy: 0.9944 - val_loss: 0.7153 - val_accuracy: 0.8855
# Epoch 58/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0776 - accuracy: 0.9943 - val_loss: 0.3059 - val_accuracy: 0.9467
# Epoch 59/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0746 - accuracy: 0.9944 - val_loss: 0.3415 - val_accuracy: 0.9417
# Epoch 60/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0764 - accuracy: 0.9940 - val_loss: 0.3824 - val_accuracy: 0.9328
# Epoch 61/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0764 - accuracy: 0.9945 - val_loss: 0.5613 - val_accuracy: 0.9162
# Epoch 62/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0793 - accuracy: 0.9937 - val_loss: 0.4848 - val_accuracy: 0.8986
# Epoch 63/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0725 - accuracy: 0.9949 - val_loss: 0.3956 - val_accuracy: 0.9257
# Epoch 64/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0767 - accuracy: 0.9943 - val_loss: 0.5664 - val_accuracy: 0.9177
# Epoch 65/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0762 - accuracy: 0.9943 - val_loss: 0.4081 - val_accuracy: 0.9409
# Epoch 66/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0741 - accuracy: 0.9944 - val_loss: 0.2815 - val_accuracy: 0.9184
# Epoch 67/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0768 - accuracy: 0.9941 - val_loss: 0.4438 - val_accuracy: 0.8874
# Epoch 68/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0727 - accuracy: 0.9951 - val_loss: 0.5775 - val_accuracy: 0.9048
# Epoch 69/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0718 - accuracy: 0.9954 - val_loss: 0.5097 - val_accuracy: 0.9294
# Epoch 70/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0749 - accuracy: 0.9948 - val_loss: 0.3124 - val_accuracy: 0.9280
# Epoch 71/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0747 - accuracy: 0.9950 - val_loss: 0.4228 - val_accuracy: 0.9156
# Epoch 72/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0723 - accuracy: 0.9949 - val_loss: 0.4514 - val_accuracy: 0.9436
# Epoch 73/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0773 - accuracy: 0.9941 - val_loss: 0.3896 - val_accuracy: 0.9371
# Epoch 74/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0714 - accuracy: 0.9949 - val_loss: 0.6273 - val_accuracy: 0.9072
# Epoch 75/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0757 - accuracy: 0.9946 - val_loss: 0.5594 - val_accuracy: 0.9252
# Epoch 76/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0758 - accuracy: 0.9947 - val_loss: 0.5404 - val_accuracy: 0.9040
# Epoch 77/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0737 - accuracy: 0.9948 - val_loss: 0.4511 - val_accuracy: 0.9075
# Epoch 78/100
# 2397/2397 [==============================] - 37s 15ms/step - loss: 0.0745 - accuracy: 0.9947 - val_loss: 0.2569 - val_accuracy: 0.9518
# Epoch 79/100
# 2397/2397 [==============================] - 36s 15ms/step - loss: 0.0763 - accuracy: 0.9946 - val_loss: 0.5723 - val_accuracy: 0.9340
# Epoch 80/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0690 - accuracy: 0.9958 - val_loss: 0.4681 - val_accuracy: 0.9384
# Epoch 81/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0758 - accuracy: 0.9949 - val_loss: 0.4584 - val_accuracy: 0.9170
# Epoch 82/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0724 - accuracy: 0.9950 - val_loss: 0.5333 - val_accuracy: 0.9319
# Epoch 83/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0733 - accuracy: 0.9948 - val_loss: 0.5213 - val_accuracy: 0.9115
# Epoch 84/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0734 - accuracy: 0.9949 - val_loss: 0.4581 - val_accuracy: 0.9031
# Epoch 85/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0769 - accuracy: 0.9946 - val_loss: 0.4114 - val_accuracy: 0.9250
# Epoch 86/100
# 2397/2397 [==============================] - 38s 16ms/step - loss: 0.0745 - accuracy: 0.9948 - val_loss: 0.6809 - val_accuracy: 0.8679
# Epoch 87/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0739 - accuracy: 0.9948 - val_loss: 0.5508 - val_accuracy: 0.9426
# Epoch 88/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0727 - accuracy: 0.9952 - val_loss: 0.6768 - val_accuracy: 0.9299
# Epoch 89/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0757 - accuracy: 0.9950 - val_loss: 0.6185 - val_accuracy: 0.8992
# Epoch 90/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0680 - accuracy: 0.9958 - val_loss: 0.6207 - val_accuracy: 0.9053
# Epoch 91/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0763 - accuracy: 0.9949 - val_loss: 0.3915 - val_accuracy: 0.9319
# Epoch 92/100
# 2397/2397 [==============================] - 34s 14ms/step - loss: 0.0728 - accuracy: 0.9956 - val_loss: 0.6446 - val_accuracy: 0.9337
# Epoch 93/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0717 - accuracy: 0.9952 - val_loss: 0.4357 - val_accuracy: 0.9268
# Epoch 94/100
# 2397/2397 [==============================] - 36s 15ms/step - loss: 0.0740 - accuracy: 0.9953 - val_loss: 0.5124 - val_accuracy: 0.9329
# Epoch 95/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0699 - accuracy: 0.9953 - val_loss: 0.3449 - val_accuracy: 0.9525
# Epoch 96/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0726 - accuracy: 0.9951 - val_loss: 0.3862 - val_accuracy: 0.9358
# Epoch 97/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0694 - accuracy: 0.9958 - val_loss: 0.5101 - val_accuracy: 0.9169
# Epoch 98/100
# 2397/2397 [==============================] - 35s 14ms/step - loss: 0.0764 - accuracy: 0.9953 - val_loss: 0.2594 - val_accuracy: 0.9395
# Epoch 99/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0689 - accuracy: 0.9953 - val_loss: 0.4821 - val_accuracy: 0.9355
# Epoch 100/100
# 2397/2397 [==============================] - 35s 15ms/step - loss: 0.0755 - accuracy: 0.9950 - val_loss: 0.4332 - val_accuracy: 0.9277

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

plt.figure(figsize=(6,12))

plt.subplot(2,1,1)

plt.xlabel('Epochs (100)')
plt.ylabel('Loss')
plt.plot(loss, 'blue', label='Training Loss')
plt.plot(val_loss, 'green', label='Validation Loss')
plt.xticks(range(0,epochs)[0::100])
plt.title('Training and Validation Loss vs Epochs')
plt.legend()

plt.subplot(2,1,2)

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(acc, 'green', label='Training Accuracy')
plt.plot(val_acc, 'red', label='Validation Accuracy')
plt.xticks(range(0,epochs)[0::100])
plt.title('Training and Validation Accuracy vs Epochs')
plt.legend()
plt.savefig("plots_perf.svg")
plt.show()

# %%
model_ecg.load_weights('./best_weights_ecg_32layer.hdf5')
y_pred = model_ecg.predict(ecg_test)
predict_test=np.argmax(y_pred, axis=1)
predict_test=predict_test.reshape(predict_test.shape[0],1)
cm=confusion_matrix(y_test_num, predict_test)
cm
# Out:
# 153/153 [==============================] - 1s 5ms/step
# array([[4761,   33],
#        [  11,   81]], dtype=int64)

# %%
(cm[1,1]+cm[0,0])/(cm[1,1]+cm[1,0]+cm[0,0]+cm[0,1]) #accuracy
# Out:
# 0.9909946786737618

# %%
cm[1,1]/(cm[1,1]+cm[1,0]) #negative prediction value
# Out:
# 0.8804347826086957

# %%
cm[0,0]/(cm[0,0]+cm[0,1]) #sensitivity
# Out:
# 0.9931163954943679

# %%
cm[0,0]/(cm[0,0]+cm[1,0]) #recall
# Out:
# 0.9976948868398994
